# %%
import pandas as pd
MSA_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/Cleaned_MSA_Data.xlsx")
MSA_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 1  Unnamed: 2        N Comp_Type  \
# 0            0.0        1275.0        24.0     93408.0  93409.0       NaN
# 1            1.0        3042.0      1209.0     10701.0  10702.0       NaN
# 2            2.0        1028.0       343.0      5584.0   5585.0       NaN
# 3            3.0        2534.0       926.0     24338.0  24339.0       NaN
# 4            4.0           NaN         NaN         NaN      NaN       NaN
# ...          ...           ...         ...         ...      ...       ...
# 2092         NaN           NaN         NaN         NaN      NaN       NaN
# 2093         NaN           NaN         NaN         NaN      NaN       NaN
# 2094         NaN           NaN         NaN         NaN      NaN       NaN
# 2095         NaN           NaN         NaN         NaN      NaN       NaN
# 2096         NaN           NaN         NaN         NaN      NaN       NaN
#
#       VN_PART           VPC Preposition Verb Lemma  ... Head. #  Head. Pos.  \
# ...

# %%
Final_MSA_df = MSA_df[MSA_df.DictionaryWV != 'N']
Final_MSA_df2 = Final_MSA_df[Final_MSA_df.DictionaryWV != 'VN']
Final_MSA_df3 = Final_MSA_df2[Final_MSA_df2.DictionaryWV != 'PART']
Final_MSA_df3
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 1  Unnamed: 2         N Comp_Type  \
# 4            4.0           NaN         NaN         NaN       NaN       NaN
# 6            6.0        2885.0       606.0     71065.0   71066.0       NaN
# 7            7.0          83.0       304.0     27326.0   27327.0       NaN
# 8            8.0         729.0      1234.0    130355.0  130356.0       NaN
# 9            9.0        1843.0        10.0    100040.0  100041.0       NaN
# ...          ...           ...         ...         ...       ...       ...
# 2082      4742.0        1008.0       323.0     86225.0   86226.0       NaN
# 2084         NaN           NaN         NaN         NaN       NaN       NaN
# 2085         NaN           NaN         NaN         NaN       NaN       NaN
# 2094         NaN           NaN         NaN         NaN       NaN       NaN
# 2095         NaN           NaN         NaN         NaN       NaN       NaN
#
# ...

# %%
Final_MSA_df3.to_excel("/Users/samanthacreel/Documents/Dissertation/Cleaned_MSA_data_final.xlsx")
