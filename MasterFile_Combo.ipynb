# %%
#import pandas as pd
lemmas_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/Results/Master_Files/Lemmas_Clean_AnalysisPrep.xlsx")
#masterfile = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/Results/Master_Files/master_fileY copy_AnalysisPrep.xlsx")

# %%
lemmas_df
# Out:
#      Comp_Type  VN_PART           VPC Preposition Verb Lemma  \
# 0          NaN      NaN         حان ل           ل        حان
# 1          NaN      NaN       يؤخذ من          من        أخذ
# 2          NaN      NaN   سيأخذ(ه) من          من        أخذ
# 3          NaN      NaN       يؤخذ مع          مع        أخذ
# 4          NaN  VN_تعين      الأخذ به           ب        أخذ
# ...        ...      ...           ...         ...        ...
# 2099       NaN    VN_تم   العزف عليها         على        عزف
# 2100       NaN    VN_تم    تسريبها فى          في       سرّب
# 2101       NaN   VN_جرى  التفتيش عليه         على       فتّش
# 2102       NaN   VN_وجب       تشخيص ب           ب       شخّص
# 2103       NaN   VN_وجب   اقتطاعه على         على      اقتطع
#
#                 Revised_Meaning  Frequency DictionaryWV UniqueEntry  \
# 0                      approach        1.0            N         NaN
# 1                     take from        2.0            N         NaN
# ...

# %%
onlyverbs_lemmas_df = lemmas_df.loc[lemmas_df['VN_PART'].isnull()]

# %%
onlyverbs_lemmas_df
# Out:
#      Comp_Type VN_PART          VPC Preposition Verb Lemma        Meaning  \
# 0          NaN     NaN        حان ل           ل        حان       approach
# 1          NaN     NaN      يؤخذ من          من        أخذ      take from
# 2          NaN     NaN  سيأخذ(ه) من          من        أخذ      take from
# 3          NaN     NaN      يؤخذ مع          مع        أخذ      take with
# 5          NaN     NaN       يتخذ ل           ل        تخذ           take
# ...        ...     ...          ...         ...        ...            ...
# 2085       NaN     NaN   كتب(ها) في          في        كتب       write in
# 2086       NaN     NaN      تكتب عن          عن        كتب    write about
# 2087       NaN     NaN      يكتب ضد          ضد        كتب  write against
# 2088       NaN     NaN      اكتب من          من        كتب     write from
# 2089       NaN     NaN      يحن إلى         إلى         حن      yearn for
#
#       Frequency DictionaryWV UniqueEntry  \
# ...

# %%
masterfile
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2       N  \
# 0            681         964      241508  241509
# 1            863          14       48860   48861
# 2            916          67       24569   24570
# 3            968         119       42371   42372
# 4            285         959      109100  109101
# ...          ...         ...         ...     ...
# 2045         756        1261      216024  216025
# 2046         470         301      112469  112470
# 2047        2993         940       87831   87832
# 2048        1008         323       86225   86226
# 2049         869          20       94923   94924
#
#                                             Concordance  \
# 0     N_P_F ل/IN مدينة/NN_S_F المسيلة/DTNN_S_F والتي...
# 1     _NEG كتاب/NN_P_M كهنة/NN_S_F مطهرون/JJ_P_M ،/P...
# 2     _S_F عادة/ADV نحو/ADV س/ABBR ؛/PUNC وهو/PRP_3_...
# 3     S_M الكربون/DTNN_S_M إذ/CC إنه/RP_EMPH غير/RP_...
# 4     JJ_S_M جدا/ADV الليوبارد/DTNN_S_M ب/IN عدد/NN_...
# ...

# %%
masterfile_Yonly = masterfile[masterfile['True Hit'] == "Y"]

# %%
masterfile_Yonly
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2       N  \
# 0            681         964      241508  241509
# 1            863          14       48860   48861
# 2            916          67       24569   24570
# 3            968         119       42371   42372
# 4            285         959      109100  109101
# ...          ...         ...         ...     ...
# 2044        1436         387       68732   68733
# 2045         756        1261      216024  216025
# 2046         470         301      112469  112470
# 2047        2993         940       87831   87832
# 2048        1008         323       86225   86226
#
#                                             Concordance  \
# 0     N_P_F ل/IN مدينة/NN_S_F المسيلة/DTNN_S_F والتي...
# 1     _NEG كتاب/NN_P_M كهنة/NN_S_F مطهرون/JJ_P_M ،/P...
# 2     _S_F عادة/ADV نحو/ADV س/ABBR ؛/PUNC وهو/PRP_3_...
# 3     S_M الكربون/DTNN_S_M إذ/CC إنه/RP_EMPH غير/RP_...
# 4     JJ_S_M جدا/ADV الليوبارد/DTNN_S_M ب/IN عدد/NN_...
# ...

# %%
combined_df = pd.merge(lemmas_df, masterfile, on="VPC")

# %%
combined_df
# Out:
#      Comp_Type VN_PART          VPC Preposition Verb Lemma      Meaning_x  \
# 0          NaN     NaN        حان ل           ل        حان       approach
# 1          NaN     NaN      يؤخذ من          من        أخذ      take from
# 2          NaN     NaN  سيأخذ(ه) من          من        أخذ      take from
# 3          NaN     NaN      يؤخذ مع          مع        أخذ      take with
# 4          NaN     NaN       يتخذ ل           ل        تخذ           take
# ...        ...     ...          ...         ...        ...            ...
# 4682       NaN     NaN   كتب(ها) في          في        كتب       write in
# 4683       NaN     NaN      تكتب عن          عن        كتب    write about
# 4684       NaN     NaN      يكتب ضد          ضد        كتب  write against
# 4685       NaN     NaN      اكتب من          من        كتب     write from
# 4686       NaN     NaN      يحن إلى         إلى         حن      yearn for
#
#       Frequency DictionaryWV UniqueEntry  \
# ...

# %%
combined_df.to_excel("combined_mastersheet.xlsx")

# %%
onlyverbs_df = combined_df.loc[combined_df['VN_PART'].isnull()]

# %%
onlyverbs_df
# Out:
#      Comp_Type VN_PART          VPC Preposition Verb Lemma      Meaning_x  \
# 0          NaN     NaN        حان ل           ل        حان       approach
# 1          NaN     NaN      يؤخذ من          من        أخذ      take from
# 2          NaN     NaN  سيأخذ(ه) من          من        أخذ      take from
# 3          NaN     NaN      يؤخذ مع          مع        أخذ      take with
# 4          NaN     NaN       يتخذ ل           ل        تخذ           take
# ...        ...     ...          ...         ...        ...            ...
# 4682       NaN     NaN   كتب(ها) في          في        كتب       write in
# 4683       NaN     NaN      تكتب عن          عن        كتب    write about
# 4684       NaN     NaN      يكتب ضد          ضد        كتب  write against
# 4685       NaN     NaN      اكتب من          من        كتب     write from
# 4686       NaN     NaN      يحن إلى         إلى         حن      yearn for
#
#       Frequency DictionaryWV UniqueEntry  \
# ...

# %%
merged_df = pd.merge(lemmas_df, masterfile, on="VPC", how="outer", indicator = True)

# %%
merged_df
# Out:
#      Comp_Type  VN_PART             VPC Preposition Verb Lemma  \
# 0          NaN      NaN           حان ل           ل        حان
# 1          NaN      NaN         يؤخذ من          من        أخذ
# 2          NaN      NaN     سيأخذ(ه) من          من        أخذ
# 3          NaN      NaN         يؤخذ مع          مع        أخذ
# 4          NaN  VN_تعين        الأخذ به           ب        أخذ
# ...        ...      ...             ...         ...        ...
# 4776       NaN      NaN  تتراوح ما بين          NaN        NaN
# 4777       NaN      NaN    يستعيض عن ب          NaN        NaN
# 4778       NaN      NaN      يطلب من(ه)         NaN        NaN
# 4779       NaN      NaN         وقضى في         NaN        NaN
# 4780       NaN      NaN       وتقسم حسب         NaN        NaN
#
#      Revised_Meaning  Frequency DictionaryWV UniqueEntry  \
# 0           approach        1.0            N         NaN
# 1          take from        2.0            N         NaN
# ...

# %%
merged_df.to_excel("merged_sheets.xlsx")

# %%
merged_df = merged_df.drop_duplicates(subset=['Concordance'])

# %%
merged_df.to_excel("merged_sheets_clean_copy.xlsx")
