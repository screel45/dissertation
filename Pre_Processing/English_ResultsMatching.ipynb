# %%
import pandas as pd
partial_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/English_results.xlsx")
# Out:
#          N                                        Concordance          Notes  \
# 0        1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...     Rel Clause
# 1        2  n/IN within/IN the/DT citizens/NNS and/CC that...        Passive
# 2        3  P 's/POS first/JJ president/NN prefers/NNS and...  End of clause
# 3        4  le/NNS ./. There/EX are/VBP advantages/NNS and...   P head of PP
# 4        5  bad/JJ effects/NNS as/IN well/NN it/PRP could/...              C
# ...    ...                                                ...            ...
# 1850  1851  ocial/JJ media/NNS to/TO some/DT extent/NN can...            NaN
# 1851  1852  and/CC ideas/NNS without/IN the/DT fear/NN of/...            NaN
# 1852  1853  NNS and/CC society/NN ./. Where/WRB it/PRP can...            NaN
# 1853  1854  mits/NNS ,/, for/IN instance/NN ,/, it/PRP can...            NaN
# 1854  1855  CD ./. therefore/RB ,/, if/IN social/JJ media/...            NaN
#
# ...

# %%
partial_df
# Out:
#          N                                        Concordance          Notes  \
# 0        1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...     Rel Clause
# 1        2  n/IN within/IN the/DT citizens/NNS and/CC that...        Passive
# 2        3  P 's/POS first/JJ president/NN prefers/NNS and...  End of clause
# 3        4  le/NNS ./. There/EX are/VBP advantages/NNS and...   P head of PP
# 4        5  bad/JJ effects/NNS as/IN well/NN it/PRP could/...              C
# ...    ...                                                ...            ...
# 1850  1851  ocial/JJ media/NNS to/TO some/DT extent/NN can...            NaN
# 1851  1852  and/CC ideas/NNS without/IN the/DT fear/NN of/...            NaN
# 1852  1853  NNS and/CC society/NN ./. Where/WRB it/PRP can...            NaN
# 1853  1854  mits/NNS ,/, for/IN instance/NN ,/, it/PRP can...            NaN
# 1854  1855  CD ./. therefore/RB ,/, if/IN social/JJ media/...            NaN
#
# ...

# %%
full_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/Full_English_Results.xlsx")
full_df
# Out:
#          N                                        Concordance  Notes  TL  VPC  \
# 0        1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...    NaN NaN  NaN
# 1        2  n/IN within/IN the/DT citizens/NNS and/CC that...    NaN NaN  NaN
# 2        3  P 's/POS first/JJ president/NN prefers/NNS and...    NaN NaN  NaN
# 3        4  P happy/JJ because/IN it/PRP is/VBZ rare/JJ to...    NaN NaN  NaN
# 4        5  DT people/NNS should/MD create/VB peace/NN and...    NaN NaN  NaN
# ...    ...                                                ...    ...  ..  ...
# 2681  2682  mits/NNS ,/, for/IN instance/NN ,/, it/PRP can...    NaN NaN  NaN
# 2682  2683  CD ./. therefore/RB ,/, if/IN social/JJ media/...    NaN NaN  NaN
# 2683  2684  both/DT individuals/NNS and/CC society/NN can/...    NaN NaN  NaN
# 2684  2685  t/VB their/PRP$ victims/NNS ./. Which/NNP will...    NaN NaN  NaN
# 2685  2686  /NN on/IN our/PRP$ world/NN and/CC it/PRP will...    NaN NaN  NaN
#
# ...

# %%
partial = partial_df['Concordance'].tolist()
full = full_df['Concordance'].tolist()
print(partial[0:10])
print(full[0:10])
# Out:
# ['s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/NNP promotes/VBZ happiness/NN in/IN which/WDT the/DT government/NN', 'n/IN within/IN the/DT citizens/NNS and/CC that/DT is/VBZ done/VBN by/IN non-profit/JJ organizations/NNS ./', "P 's/POS first/JJ president/NN prefers/NNS and/CC wants/VBZ ,/, in/IN which/WDT people/NNS should/MD create/V", 'le/NNS ./. There/EX are/VBP advantages/NNS and/CC disadvantages/VBZ some/DT of/IN them/PRP are/VBP good/JJ and/CC som', 'bad/JJ effects/NNS as/IN well/NN it/PRP could/MD be/VB dangerous/JJ for/IN our/PRP$ health/NN ./. Especi', 'ry/RB bad/JJ ,/, all/DT people/NNS want/VBP to/TO be/VB famous/JJ on/IN the/DT social/JJ media/NNS ,/, so', 'people/NNS the/DT society/NN because/IN its/PRP$ affecting/VBG them/PRP by/IN making/VBG people/NNS more/RBR mor', 'ffect/JJ students/NNS too/RB ,/, they/PRP will/MD be/VB always/RB on/IN their/PRP$ phones/NNS as/IN if/IN', 'BZ control/VB the/DT network/NN ,/, but/CC it/PRP is/VBZ dangerous/JJ for/IN our/PRP$ mind/NN 
# ...

# %%
cond = partial_df['Concordance'].isin(full_df['Concordance'])
full_df.drop(full_df[cond].index, inplace = True)
full_df
# Out:
# <ipython-input-8-fc82d10c2e72>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   full_df.drop(full_df[cond].index, inplace = True)
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-8-fc82d10c2e72> in <module>
#       1 cond = partial_df['Concordance'].isin(full_df['Concordance'])
# ----> 2 full_df.drop(full_df[cond].index, inplace = True)
#       3 full_df
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# ...

# %%
final_df = full_df[full_df.Set != '*"/"VB* * *"/"IN']
final_df
# Out:
#          N                                        Concordance  Notes  TL  VPC  \
# 3        4  P happy/JJ because/IN it/PRP is/VBZ rare/JJ to...    NaN NaN  NaN
# 4        5  DT people/NNS should/MD create/VB peace/NN and...    NaN NaN  NaN
# 10      11  eir/PRP$ phones/NNS and/CC they/PRP do/VBP n't...    NaN NaN  NaN
# 11      12  e/VB to/TO study/VB and/CC they/PRP do/VBP n't...    NaN NaN  NaN
# 14      15  ,/, video/NN game/NN and/CC computer/NN ./. To...    NaN NaN  NaN
# ...    ...                                                ...    ...  ..  ...
# 2674  2675  gh/IN the/DT internet/NN ,/, and/CC it/PRP can...    NaN NaN  NaN
# 2675  2676  ativity/NN ./. An/DT influencer/NN can/MD help...    NaN NaN  NaN
# 2683  2684  both/DT individuals/NNS and/CC society/NN can/...    NaN NaN  NaN
# 2684  2685  t/VB their/PRP$ victims/NNS ./. Which/NNP will...    NaN NaN  NaN
# 2685  2686  /NN on/IN our/PRP$ world/NN and/CC it/PRP will...    NaN NaN  NaN
#
# ...
