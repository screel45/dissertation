# %%
it_samplef = []
with open("/Users/samanthacreel/Documents/Dissertation/Corpora/MSA_Corpus/it_8_test.txt", encoding='utf-8' ) as f:
    it_samplef = f.read().splitlines()
print(it_samplef[0:250])
# Out:
# ['عالم/NN_S_M التقنية/DTNN_S_F', '\u200e/DTNN_S_M', '\u200eبواسطة/NN_S_F هيفاء/NN_S_M من/IN أكثر/JJR_S_M الأمور/DTNN_P_F متعة/NN_S_F في/IN قراءة/NN_S_F الكتب/DTNN_P_F الإلكترونية/DTJJ_S_F هي/PRP_3_S_F استخدام/NN_S_M الآي/DTJJ_S_M باد/NN_S_M و/CC رغم/NN_S_M أن/CC الجهاز/DTNN_S_M لا/RP_NEG يعرف/VBZP_3_S_M ك/IN قارئ/NN_S_M كتب/NN_P_F إلكتروني/NN_S_M إلا/CC أنه/CC لا/RP_NEG تكاد/VBZ_3_S_F تجد/VBZ_2_S_M من/IN يشكك/VBZP_3_S_M في/IN كونه/NN$_S_M قارئ/NNSYN_S_M كتب/NN_P_F ممتاز/JJ_S_M ولعل/ADV الإحصائيات/DTNN_P_F الأخيرة/DTJJ_S_F والتي/WP تقارن/VBZ_3_S_F بينه/IN وبين/IN الأجهزة/DTNN_P_F المخصصة/DTJJ_S_F ك/IN ندل/NN_S_M مثل/NN_S_M ا/NAUNATION تؤكد/VBZ_3_S_F ما/WP أقوله/VBD$_3_S_M كمبادره/NN$_S_M أولى/JJ_S_F تم/VBD_3_S_M إنشاء/NN_S_M موسوعة/JJ_S_F ل/IN الكتب/DTNN_S_M العربية/DTJJP_S_F ب/IN صيغة/NN_S_F وهي/PRP_3_S_F الصيغة/DTNN_S_F المدعومة/DTJJ_S_F من/IN قبل/ADV وهو/PRP_3_S_M تطبيق/NN_S_M القراءة/DTNN_S_F المستخدم/DTJJ_S_M على/IN أجهزة/NN_P_F الآي/DTNN_S_M باد/NN_S_M و/CC الآي/DTNN_S_M فون/NN_
# ...

# %%
with open("/Users/samanthacreel/Documents/Dissertation/Corpora/newswire.txt", encoding='utf-8') as fp: 
    data = fp.read().splitlines()
print(len(data))
# out1 = open('newssplit1.txt', 'w') 
# out2 = open('newssplit2.txt', 'w') 
# halfway = len(data) / 2 
# out1.write(data[0:halfway]) 
# out2.write(data[halfway+1:]) 
# out1.close() 
# out2.close()
# Out:
# 2339522

# %%
totallines= len(data)
splitlength = totallines/2
print(splitlength)
# Out:
# 1169761.0

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
file1 = data[0:1169761]
print(len(file1))
file2 = data[1169761:]
print(len(file2))
# Out:
# 1169761
# 1169761

# %%
print(file1[1169760])
# Out:
# الجزائر/DTNNP_S_F حصدت/VBD_3_S_F الجزائر/DTNNP_S_F ذهبية/JJ_S_F خلال/ADV منافسات/NN_P_F البطولة/DTNN_S_F المغاربية/DTJJ_S_F التاسعة/DTJJ_S_F ل/IN السباحة/DTNN_S_F الفئات/DTNN_P_F الشابة/DTJJ_S_F التي/WP احتضنها/NN$_S_M مسبح/NN_S_M اول/JJ_S_M ماي/JJ_S_M الجزائر/DTNNP_S_F يومي/NN$_S_M أبريل/NN_S_M و/CC ماي/JJ_S_M

# %%
print(file2[0:15])
# Out:
# ['وإحتلت/VBD_3_S_F الجزائر/DTNNP_S_F المركز/DTNN_S_M الاول/DTJJ_S_M في/IN الترتيب/DTNN_S_M العام/DTJJ_S_M ل/IN المنافسة/DTNN_S_F بعد/ADV ان/CC جمعت/VBD_3_S_F ميدالية/NN_S_F ذهبية/JJ_S_F فضية/JJ_S_F ب/IN رونزية/JJ_S_F متبوعة/JJ_S_F ب/IN تونس/NN_S_M التي/WP تمكنت/VBD_3_S_F من/IN حصد/NN_S_M ميدالية/NN_S_F ذهبية/JJ_S_F فضية/JJ_S_F ب/IN رونزية/JJ_S_F', 'في/IN حين/CC احتل/VBD_3_S_M المغرب/DTNN_S_M المركز/DTNN_S_M الثالث/DTJJ_S_M ب/IN ميدالية/NN_S_F ذهبيات/JJ_P_F فضية/JJ_S_F ب/IN رونزية/JJ_S_F', '?/PUNC اليوم/DTNN_S_M العالمي/DTJJ_S_M ل/IN الصحافة/DTNN_S_F فريقا/NN_D_M نادي/NN_S_M الصحافة/DTNN_S_F الرياضية/DTJJ_S_F و/CC يومية/JJ_S_F ليبيرتي/VBZ_3_S_M في/IN نهائي/JJ_S_M دورة/NN_S_F كرة/NN_S_F القدم/DTNN_S_M', 'الجزائر/DTNNP_S_F سينشط/VBF_3_S_M فريقا/NN_D_M نادي/NN_S_M الصحافة/DTNN_S_F الرياضية/DTJJ_S_F و/CC يومية/JJ_S_F ليبيرتي/VBZ_3_S_M يوم/NN_S_M غد/NN_S_M الثلاثاء/DTNN_S_M ر/FN ب/IN ملعب/NN_S_M أوت/VBD_3_S_F الجزائر/DTNNP_S_F نهائي/JJ_S_M دورة/NN_S_F في/IN كرة/NN_S_F القدم/DTNN_S_M التي/W
# ...

# %%
with open('ency1.txt', mode='wt', encoding='utf-8') as myfile:
    myfile.write('\n'.join(file1))

# %%
with open('ency2.txt', mode='wt', encoding='utf-8') as myfile:
    myfile.write('\n'.join(file2))

# %%
for line in file1:
    if line in file2:
        print(line)
# Out:
# اليوم/DTNN_S_M
# أمريكا/NNP_S_F
# أمريكا/NNP_S_F
# وفي/IN مباراة/NN_S_F أسترالي/NN_S_M ا/NAUNATION أحرز/VBD_3_S_M هدف/NN_S_M العراق/DTNNP_S_M عماد/NN_S_M محمد/NNP_S_M من/IN ضربة/NN_S_F مزدوجة/JJ_S_F خلفية/JJ_S_F ل/IN كرة/NN_S_F مرتدة/JJ_S_F على/IN حدود/NN_P_F منطقة/NN_S_F الجزاء/DTNN_S_M في/IN الدقيقة/DTNN_S_F من/IN الشوط/DTNN_S_M الثاني/DTJJ_S_M
# وهو/PRP_3_S_M هدفه/NN$_S_M الثاني/DTJJ_S_M في/IN البطولة/DTNN_S_F بعد/ADV الهدف/DTNN_S_M الذي/WP سجله/VBF$_3_S_M في/IN منتخب/NN_S_M البرتغال/DTNNP_S_F
# وجاء/VBD_3_S_M هدف/NN_S_M العراق/DTNNP_S_M في/IN ظل/NN_S_M سيطرة/NN_S_F أسترالية/JJP_S_F على/IN معظم/DET فترات/NN_P_F المباراة/DTNN_S_F و/CC استحواذ/NN_S_M على/IN ألعاب/NN_P_F الهواء/DTNN_S_M و/CC إهدار/NN_S_M العديد/DTNN_S_M من/IN الفرص/DTNN_P_F السهلة/DTJJ_S_F من/IN جانب/NN_S_M المنتخب/DTNN_S_M الأسترالي/DTJJP_S_M
# ولكن/CC تغير/NN_S_M سير/NN_S_M المباراة/DTNN_S_F إلى/IN سيطرة/NN_S_F عراقية/JJP_S_F بعد/ADV هدف/NN_S_M الفوز/DTNN_S_M
# ...
