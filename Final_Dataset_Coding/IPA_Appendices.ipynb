# %%
import pandas as pd
L1Arabic_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/L1Arabic_Appendix.xlsx")
ZArabic_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/ZArabic_Appendix.xlsx")

# %%
L1Arabic_df
# Out:
#      Unnamed: 0       VPC             IPA              English  Raw Freq  \
# 0             1     قام ب       qa:ma bi-  carry out/undertake        54
# 1             2   أدى إلى    ʔadda: ʔila:              lead to        26
# 2             3   حصل على   ħasˤala ʕala:               obtain        24
# 3             4   وصل إلى   wasˤala ʔila:                reach        19
# 4             5   عمل على    ʕamala ʕala:              work on        18
# ..          ...       ...             ...                  ...       ...
# 267         268    نشأ من      naʃaʔa min            grow from         1
# 268         269    نظر في     naðˤara fi:             consider         1
# 269         270    نفر عن      nafara ʕan         be averse to         1
# 270         271     هام ب       ha:ma bi-         fall in love         1
# 271         272  واظب على  wa:ðˤaba ʕala:        continue with         1
#
#      Norm Freq
# 0        34.17
# 1        16.45
# 2        15.19
# 3        12.02
# ...

# %%
df_2 = pd.merge(L1Arabic_df, ZArabic_df, on=["VPC"], how='right')

# %%
df_2
# Out:
#     Unnamed: 0_x      VPC          IPA_x            English_x  Raw Freq_x  \
# 0            1.0    قام ب      qa:ma bi-  carry out/undertake        54.0
# 1            2.0  أدى إلى   ʔadda: ʔila:              lead to        26.0
# 2            3.0  حصل على  ħasˤala ʕala:               obtain        24.0
# 3            4.0  وصل إلى  wasˤala ʔila:                reach        19.0
# 4            5.0  عمل على   ʕamala ʕala:              work on        18.0
# ..           ...      ...            ...                  ...         ...
# 67         257.0   فكر في    fakkara fi:          think about         1.0
# 68         262.0    لاق ب      la:qa bi-                befit         1.0
# 69         265.0   نتج عن     nataʒa ʕan          result from         1.0
# 70           NaN   سبب في            NaN                  NaN         NaN
# 71           NaN    أخذ ب            NaN                  NaN         NaN
#
#     Norm Freq_x  Unnamed: 0_y  IPA_y  English_y  Raw Freq_y  Norm Freq_y
# ...

# %%
df_2.to_excel("/Users/samanthacreel/Documents/Dissertation/ZArabic_Appendix_Filled.xlsx")
