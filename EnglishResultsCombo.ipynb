# %%
import pandas as pd
old_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/Full_English_Results.xlsx")
new_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/EnglishFINALMISSING.xlsx")
old_df
# Out:
#          N                                        Concordance          Notes  \
# 0        1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...     Rel Clause
# 1        2  n/IN within/IN the/DT citizens/NNS and/CC that...        Passive
# 2        3  P 's/POS first/JJ president/NN prefers/NNS and...  End of clause
# 3        6  le/NNS ./. There/EX are/VBP advantages/NNS and...   P head of PP
# 4        7  bad/JJ effects/NNS as/IN well/NN it/PRP could/...              C
# ...    ...                                                ...            ...
# 2681  2675  gh/IN the/DT internet/NN ,/, and/CC it/PRP can...            NaN
# 2682  2676  ativity/NN ./. An/DT influencer/NN can/MD help...            NaN
# 2683  2684  both/DT individuals/NNS and/CC society/NN can/...          PrepV
# 2684  2685  t/VB their/PRP$ victims/NNS ./. Which/NNP will...          PrepV
# 2685  2686  /NN on/IN our/PRP$ world/NN and/CC it/PRP will...          PrepV
#
# ...

# %%
new_df
# Out:
#          N                                        Concordance  Notes  TL  VPC  \
# 0        1  DT people/NNS should/MD create/VB peace/NN and...    NaN NaN  NaN
# 1        2  JJ to/TO what/WP their/PRP$ greatest/JJS ruler...    NaN NaN  NaN
# 2        3  IN non-profit/JJ organizations/NNS ./. People/...    NaN NaN  NaN
# 3        4  thin/IN the/DT citizens/NNS and/CC that/DT is/...    NaN NaN  NaN
# 4        5  a/DT hot/JJ season/NN ./. However/RB ,/, rain/...    NaN NaN  NaN
# ...    ...                                                ...    ...  ..  ...
# 2453  2454  d/CC society/NN ./. Where/WRB it/PRP can/MD be...    NaN NaN  NaN
# 2454  2455  huge/JJ impact/NN on/IN the/DT society/NN we/P...    NaN NaN  NaN
# 2455  2456  s/NNS without/IN the/DT fear/NN of/IN getting/...    NaN NaN  NaN
# 2456  2457  NN can/MD benefit/VB from/IN if/IN it/PRP was/...    NaN NaN  NaN
# 2457  2458  both/DT individuals/NNS and/CC society/NN can/...    NaN NaN  NaN
#
# ...

# %%
merged_df = pd.merge(old_df, new_df, on="Concordance", how="outer", indicator = True)
merged_df
# Out:
#       N_x                                        Concordance        Notes_x  \
# 0     1.0  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...     Rel Clause
# 1     2.0  n/IN within/IN the/DT citizens/NNS and/CC that...        Passive
# 2     3.0  P 's/POS first/JJ president/NN prefers/NNS and...  End of clause
# 3     6.0  le/NNS ./. There/EX are/VBP advantages/NNS and...   P head of PP
# 4     7.0  bad/JJ effects/NNS as/IN well/NN it/PRP could/...              C
# ...   ...                                                ...            ...
# 4224  NaN  NS ,/, for/IN instance/NN ,/, it/PRP can/MD be...            NaN
# 4225  NaN  d/CC society/NN ./. Where/WRB it/PRP can/MD be...            NaN
# 4226  NaN  huge/JJ impact/NN on/IN the/DT society/NN we/P...            NaN
# 4227  NaN  s/NNS without/IN the/DT fear/NN of/IN getting/...            NaN
# 4228  NaN  NN can/MD benefit/VB from/IN if/IN it/PRP was/...            NaN
#
# ...

# %%
merged_df = merged_df.drop_duplicates(subset=['Concordance'])
merged_df
# Out:
#       N_x                                        Concordance        Notes_x  \
# 0     1.0  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...     Rel Clause
# 1     2.0  n/IN within/IN the/DT citizens/NNS and/CC that...        Passive
# 2     3.0  P 's/POS first/JJ president/NN prefers/NNS and...  End of clause
# 3     6.0  le/NNS ./. There/EX are/VBP advantages/NNS and...   P head of PP
# 4     7.0  bad/JJ effects/NNS as/IN well/NN it/PRP could/...              C
# ...   ...                                                ...            ...
# 4224  NaN  NS ,/, for/IN instance/NN ,/, it/PRP can/MD be...            NaN
# 4225  NaN  d/CC society/NN ./. Where/WRB it/PRP can/MD be...            NaN
# 4226  NaN  huge/JJ impact/NN on/IN the/DT society/NN we/P...            NaN
# 4227  NaN  s/NNS without/IN the/DT fear/NN of/IN getting/...            NaN
# 4228  NaN  NN can/MD benefit/VB from/IN if/IN it/PRP was/...            NaN
#
# ...

# %%
merged_df.to_excel("English_FINAL.xlsx")

# %%
final_df = pd.concat([old_df, new_df])
final_df
# Out:
#          N                                        Concordance          Notes  \
# 0        1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...     Rel Clause
# 1        2  n/IN within/IN the/DT citizens/NNS and/CC that...        Passive
# 2        3  P 's/POS first/JJ president/NN prefers/NNS and...  End of clause
# 3        6  le/NNS ./. There/EX are/VBP advantages/NNS and...   P head of PP
# 4        7  bad/JJ effects/NNS as/IN well/NN it/PRP could/...              C
# ...    ...                                                ...            ...
# 2453  2454  d/CC society/NN ./. Where/WRB it/PRP can/MD be...            NaN
# 2454  2455  huge/JJ impact/NN on/IN the/DT society/NN we/P...            NaN
# 2455  2456  s/NNS without/IN the/DT fear/NN of/IN getting/...            NaN
# 2456  2457  NN can/MD benefit/VB from/IN if/IN it/PRP was/...            NaN
# 2457  2458  both/DT individuals/NNS and/CC society/NN can/...            NaN
#
# ...

# %%
final_df = final_df.drop_duplicates(subset=['Concordance'])
final_df
# Out:
#          N                                        Concordance          Notes  \
# 0        1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...     Rel Clause
# 1        2  n/IN within/IN the/DT citizens/NNS and/CC that...        Passive
# 2        3  P 's/POS first/JJ president/NN prefers/NNS and...  End of clause
# 3        6  le/NNS ./. There/EX are/VBP advantages/NNS and...   P head of PP
# 4        7  bad/JJ effects/NNS as/IN well/NN it/PRP could/...              C
# ...    ...                                                ...            ...
# 2452  2453  NS ,/, for/IN instance/NN ,/, it/PRP can/MD be...            NaN
# 2453  2454  d/CC society/NN ./. Where/WRB it/PRP can/MD be...            NaN
# 2454  2455  huge/JJ impact/NN on/IN the/DT society/NN we/P...            NaN
# 2455  2456  s/NNS without/IN the/DT fear/NN of/IN getting/...            NaN
# 2456  2457  NN can/MD benefit/VB from/IN if/IN it/PRP was/...            NaN
#
# ...

# %%
final_df.to_excel("English_FINAL.xlsx")

# %%
#import pandas as pd
old_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/Final_Datasets/English_FINAL.xlsx")
new_df = pd.read_excel("/Users/samanthacreel/Documents/Dissertation/Final_Datasets/EnglishTO.xlsx")
old_df
# Out:
#       Unnamed: 0     N                                        Concordance  \
# 0              0     1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...
# 1              1     2  n/IN within/IN the/DT citizens/NNS and/CC that...
# 2              2     3  P 's/POS first/JJ president/NN prefers/NNS and...
# 3              3     6  le/NNS ./. There/EX are/VBP advantages/NNS and...
# 4              4     7  bad/JJ effects/NNS as/IN well/NN it/PRP could/...
# ...          ...   ...                                                ...
# 4178        2452  2453  NS ,/, for/IN instance/NN ,/, it/PRP can/MD be...
# 4179        2453  2454  d/CC society/NN ./. Where/WRB it/PRP can/MD be...
# 4180        2454  2455  huge/JJ impact/NN on/IN the/DT society/NN we/P...
# 4181        2455  2456  s/NNS without/IN the/DT fear/NN of/IN getting/...
# 4182        2456  2457  NN can/MD benefit/VB from/IN if/IN it/PRP was/...
#
#               Notes  VPC Preposition Lemma   VT   GT               Set  ...  \
# ...

# %%
new_df
# Out:
#        N                                        Concordance Hit  \
# 0      1  untries/NNS make/VBP the/DT heat/NN unbearable...   N
# 1      2  /IN which/WDT the/DT government/NN 's/POS goal...   N
# 2      3  in/IN the/DT morning/NN ,/, get/VB ready/JJ to...   N
# 3      4  ements/NNS in/IN the/DT UAE/NNP have/VBP been/...   N
# 4      5  CC they/PRP 'll/MD be/VB attracted/VBN ,/, and...   Y
# ..   ...                                                ...  ..
# 865  866  IN a/DT society/NN like/IN you/PRP might/MD be...   Y
# 866  867  from/IN his/PRP$ or/CC her/PRP$ viewers/NNS to...   N
# 867  868  ich/WDT means/VBZ more/JJR jobs/NNS ,/, which/...   Y
# 868  869  should/MD be/VB careful/JJ of/IN how/WRB they/...   N
# 869  870  /RB know/VBP what/WP those/DT actions/NNS will...   Y
#
#                 Set  Tag  Word #  Sent. #  Sent. Pos.  Para. #  Para. Pos.  \
# 0    *"/"VB* *"/"TO  NaN      70        0          68        0          68
# ...

# %%
new_df = new_df[new_df['Hit']=='Y']
new_df
# Out:
#        N                                        Concordance Hit  \
# 4      5  CC they/PRP 'll/MD be/VB attracted/VBN ,/, and...   Y
# 10    11  things/NNS that/WDT social/JJ media/NNS could/...   Y
# 11    12  NP ,/, there/EX are/VBP many/JJ new/JJ things/...   Y
# 12    13  n/NN on/IN social/JJ media/NNS ,/, and/CC that...   Y
# 14    15  ir/PRP$ health/NN ./. social/JJ media/NNS also...   Y
# ..   ...                                                ...  ..
# 856  857  RP a/DT faster/RBR and/CC easier/JJR way/NN to...   Y
# 862  863  tening/VBG because/IN their/PRP$ eyes/NNS are/...   Y
# 865  866  IN a/DT society/NN like/IN you/PRP might/MD be...   Y
# 867  868  ich/WDT means/VBZ more/JJR jobs/NNS ,/, which/...   Y
# 869  870  /RB know/VBP what/WP those/DT actions/NNS will...   Y
#
#                 Set  Tag  Word #  Sent. #  Sent. Pos.  Para. #  Para. Pos.  \
# 4    *"/"VB* *"/"TO  NaN     167        0         165        0         165
# ...

# %%
new_df = new_df.drop(columns=['Hit'])
new_df
# Out:
#        N                                        Concordance             Set  \
# 4      5  CC they/PRP 'll/MD be/VB attracted/VBN ,/, and...  *"/"VB* *"/"TO
# 10    11  things/NNS that/WDT social/JJ media/NNS could/...  *"/"VB* *"/"TO
# 11    12  NP ,/, there/EX are/VBP many/JJ new/JJ things/...  *"/"VB* *"/"TO
# 12    13  n/NN on/IN social/JJ media/NNS ,/, and/CC that...  *"/"VB* *"/"TO
# 14    15  ir/PRP$ health/NN ./. social/JJ media/NNS also...  *"/"VB* *"/"TO
# ..   ...                                                ...             ...
# 856  857  RP a/DT faster/RBR and/CC easier/JJR way/NN to...  *"/"VB* *"/"TO
# 862  863  tening/VBG because/IN their/PRP$ eyes/NNS are/...  *"/"VB* *"/"TO
# 865  866  IN a/DT society/NN like/IN you/PRP might/MD be...  *"/"VB* *"/"TO
# 867  868  ich/WDT means/VBZ more/JJR jobs/NNS ,/, which/...  *"/"VB* *"/"TO
# 869  870  /RB know/VBP what/WP those/DT actions/NNS will...  *"/"VB* *"/"TO
#
# ...

# %%
new_df["Notes"] = ""
new_df["VPC"] = ""
new_df["Preposition"] = ""
new_df["Lemma"] = ""
new_df["VT"] = ""
new_df["GT"] = ""
new_df
# Out:
#        N                                        Concordance             Set  \
# 4      5  CC they/PRP 'll/MD be/VB attracted/VBN ,/, and...  *"/"VB* *"/"TO
# 10    11  things/NNS that/WDT social/JJ media/NNS could/...  *"/"VB* *"/"TO
# 11    12  NP ,/, there/EX are/VBP many/JJ new/JJ things/...  *"/"VB* *"/"TO
# 12    13  n/NN on/IN social/JJ media/NNS ,/, and/CC that...  *"/"VB* *"/"TO
# 14    15  ir/PRP$ health/NN ./. social/JJ media/NNS also...  *"/"VB* *"/"TO
# ..   ...                                                ...             ...
# 856  857  RP a/DT faster/RBR and/CC easier/JJR way/NN to...  *"/"VB* *"/"TO
# 862  863  tening/VBG because/IN their/PRP$ eyes/NNS are/...  *"/"VB* *"/"TO
# 865  866  IN a/DT society/NN like/IN you/PRP might/MD be...  *"/"VB* *"/"TO
# 867  868  ich/WDT means/VBZ more/JJR jobs/NNS ,/, which/...  *"/"VB* *"/"TO
# 869  870  /RB know/VBP what/WP those/DT actions/NNS will...  *"/"VB* *"/"TO
#
# ...

# %%
new_df = new_df.drop(columns=['Notes','VPC','Preposition','Lemma','VT','GT'])
new_df
# Out:
#        N                                        Concordance             Set  \
# 4      5  CC they/PRP 'll/MD be/VB attracted/VBN ,/, and...  *"/"VB* *"/"TO
# 10    11  things/NNS that/WDT social/JJ media/NNS could/...  *"/"VB* *"/"TO
# 11    12  NP ,/, there/EX are/VBP many/JJ new/JJ things/...  *"/"VB* *"/"TO
# 12    13  n/NN on/IN social/JJ media/NNS ,/, and/CC that...  *"/"VB* *"/"TO
# 14    15  ir/PRP$ health/NN ./. social/JJ media/NNS also...  *"/"VB* *"/"TO
# ..   ...                                                ...             ...
# 856  857  RP a/DT faster/RBR and/CC easier/JJR way/NN to...  *"/"VB* *"/"TO
# 862  863  tening/VBG because/IN their/PRP$ eyes/NNS are/...  *"/"VB* *"/"TO
# 865  866  IN a/DT society/NN like/IN you/PRP might/MD be...  *"/"VB* *"/"TO
# 867  868  ich/WDT means/VBZ more/JJR jobs/NNS ,/, which/...  *"/"VB* *"/"TO
# 869  870  /RB know/VBP what/WP those/DT actions/NNS will...  *"/"VB* *"/"TO
#
# ...

# %%
#new_df.insert(2, "Notes", "")
new_df.insert(3, "VPC", "")
new_df.insert(4, "Preposition", "")
new_df.insert(5, "Lemma", "")
new_df.insert(6, "VT", "")
new_df.insert(7, "GT", "")
new_df
# Out:
#        N                                        Concordance Notes VPC  \
# 4      5  CC they/PRP 'll/MD be/VB attracted/VBN ,/, and...
# 10    11  things/NNS that/WDT social/JJ media/NNS could/...
# 11    12  NP ,/, there/EX are/VBP many/JJ new/JJ things/...
# 12    13  n/NN on/IN social/JJ media/NNS ,/, and/CC that...
# 14    15  ir/PRP$ health/NN ./. social/JJ media/NNS also...
# ..   ...                                                ...   ...  ..
# 856  857  RP a/DT faster/RBR and/CC easier/JJR way/NN to...
# 862  863  tening/VBG because/IN their/PRP$ eyes/NNS are/...
# 865  866  IN a/DT society/NN like/IN you/PRP might/MD be...
# 867  868  ich/WDT means/VBZ more/JJR jobs/NNS ,/, which/...
# 869  870  /RB know/VBP what/WP those/DT actions/NNS will...
#
#     Preposition Lemma VT GT             Set  Tag  ...  Sent. Pos.  Para. #  \
# 4                            *"/"VB* *"/"TO  NaN  ...         165        0
# ...

# %%
final_final_df = pd.concat([old_df, new_df])
final_final_df
# Out:
#      Unnamed: 0    N                                        Concordance  \
# 0           0.0    1  s/NNS or/and/VBP downpours/NNS ./. The/DT UAE/...
# 1           1.0    2  n/IN within/IN the/DT citizens/NNS and/CC that...
# 2           2.0    3  P 's/POS first/JJ president/NN prefers/NNS and...
# 3           3.0    6  le/NNS ./. There/EX are/VBP advantages/NNS and...
# 4           4.0    7  bad/JJ effects/NNS as/IN well/NN it/PRP could/...
# ..          ...  ...                                                ...
# 856         NaN  857  RP a/DT faster/RBR and/CC easier/JJR way/NN to...
# 862         NaN  863  tening/VBG because/IN their/PRP$ eyes/NNS are/...
# 865         NaN  866  IN a/DT society/NN like/IN you/PRP might/MD be...
# 867         NaN  868  ich/WDT means/VBZ more/JJR jobs/NNS ,/, which/...
# 869         NaN  870  /RB know/VBP what/WP those/DT actions/NNS will...
#
#              Notes  VPC Preposition Lemma   VT   GT               Set  ...  \
# ...

# %%
final_final_df.to_excel("/Users/samanthacreel/Documents/Dissertation/Final_Datasets/English_FINALFINAL.xlsx")
